# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
cause=['Chronic diseases','Unintentional Injuries','Alzheimers','Infuenza and Pneumonia','Sepsis','Others']
per=np.array([62,5,4,2,1,26])

# %%
type(per)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(10,10))

# %%
explode=(0.05,0,0,0,0,0)

# %%
plt.pie(per,labels=cause,explode=explode)
plt.show()

# %%
plt.pie(per,labels=cause,explode=explode,startangle=50)
plt.show()

# %%
plt.pie(per,labels=cause,explode=explode,startangle=70)
plt.show()

# %%
plt.pie(per,labels=cause,explode=explode,startangle=100)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.pie(per,labels=cause,explode=explode,startangle=100)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(per,labels=cause,explode=explode,startangle=100)
plt.show()

# %%
plt.pie(per,labels=cause,explode=explode,startangle=100)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(per,labels=cause,explode=explode,startangle=100,autopct='%1.1f%%')
plt.title('Ohio State - 2012 : Leading Causes Of Death')
plt.show()
